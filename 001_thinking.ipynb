# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
from anthropic.types import Message

# Magic string to trigger redacted thinking
thinking_test_str = "ANTHROPIC_MAGIC_STRING_TRIGGER_REDACTED_THINKING_46C9A13E193C177646C7398A98432ECCCE4C1253D5E2D82641AC0E52CC2876CB"


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(
    messages,
    system=None,
    temperature=1.0,
    stop_sequences=[],
    tools=None,
    thinking=False,
    thinking_budget=1024
):
    params = {
        "model": model,
        "max_tokens": 4000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if thinking:
        params["thinking"] = {
            "type": "enabled",
            "budget_tokens": thinking_budget
        }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
messages = []

add_user_message(messages, "Write a one paragraph guide to recursion.")

chat(messages, thinking=True)
# Out:
# Message(id='msg_011CdXFw7tR54vf6tnPLiCxx', container=None, content=[ThinkingBlock(signature='...', thinking="The user wants a one-paragraph guide to recursion. I should explain what recursion is, why it's useful, how it works, and include some key concepts like base cases and recursive cases. I'll try to make it clear and accessible while being concise.\n\nKey points to cover:\n- Definition of recursion (a function calling itself)\n- Base case (stopping condition)\n- Recursive case (the function calling itself with a simpler problem)\n- Why it's useful\n- Maybe a simple example or reference to one\n\nLet me write a comprehensive paragraph.", type='thinking'), TextBlock(citations=None, text="# A Guide to Recursion\n\nRecursion is a programming technique where a function solves a problem by calling itself with simpler or smaller inputs until it reaches a base case—a condition that stops the recursion and returns a value without further calls. Every recursive function must have at least two components: a base case (the simplest version of the problem with a direct answer) and a recursive case (where the function calls itself on a smaller subset of the problem). For example, calculating a factorial can be solved recursively by recognizing that 5! = 5 × 4!, which equals 5 × 4 × 3!, and so on, until you reach the base case of 0! = 1. Recursion is particularly elegant for problems with inherently self-similar structures like tree traversal, sorting algorithms, and mathematical sequences, but it's important to ensure your base case is reachable and that each recursive call makes progress toward it—otherwise your function will cause a stack overflow. While recursion can be intuitive and clean, iterative approaches are sometimes more efficient since each function call uses memory on the call stack; nonetheless, understanding recursion is essential for writing solutions to naturally recursive problems.", type='text')], model='claude-haiku-4-5-20251001', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=45, output_tokens=388, output_tokens_details=OutputTokensDetails(thinking_tokens=126), server_tool_use=None, service_tier='standard'))
